# %% [markdown]
# # Adversarial Attack Evaluation
# Run various TextAttack recipes against the robust model.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))
from src.attack_pipeline import pipeline

text = "I really enjoyed this fantastic product, it works perfectly."
attack_result = pipeline.attack_text(text, attack_name="textfooler")
print(attack_result)
