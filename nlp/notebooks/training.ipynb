# %% [markdown]
# # Robust Sentiment Analysis Training
# This notebook contains the training process for the robust sentiment analysis model.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../src')

from train import main

# Uncomment to run training
# main()
