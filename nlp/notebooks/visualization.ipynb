# %% [markdown]
# # Visualization
# Plotting results from the adversarial evaluations.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))
from src.visualization import plot_attack_success_rate
from src.evaluation import compute_metrics

# Example mock data
metrics = {
    'textfooler': {'attack_success_rate': 0.15},
    'deepwordbug': {'attack_success_rate': 0.20},
    'bae': {'attack_success_rate': 0.10}
}
plot_attack_success_rate(metrics)
